# %% [markdown]
# # Contact
#
# [Terence Lim](https://www.linkedin.com/in/terencelim)

# %% [markdown]
# # 1. Agentic framework for empirical research in quantitative finance
#
# **QRAFTI: Quantitative Research Assistants with Financial Tools and Intelligence**
#
# Quantitative financial research is a multi-stage process that typically involves generating ideas grounded in economic intuition, acquiring and cleaning data, constructing signals and factors, backtesting portfolios, adjusting for risk, evaluating robustness to model uncertainty and data-mining bias, and producing research reports that enable peer verification. Recent advances in agentic AI---that is, LLM-centered systems that can plan, invoke external tools, and revise actions in response to observed outputs---create an opportunity to assist parts of this workflow while potentially improving reproducibility and explainability. We introduce QRAFTI, a multi-agent framework intended to emulate parts of a quantitative research team and support equity factor research on large financial panel datasets. It integrates an empirical research toolkit for panel data with MCP servers that expose data access, factor construction, and custom coding operations as callable tools. Through this architecture, QRAFTI can help replicate established factors, formulate and test new signals, and generate standardized research reports accompanied by narrative analysis and computational traces. Our initial evaluations suggest that, on multi-step empirical research tasks, the system offers better performance and explainability using chained tool calls and reflection-based planning than dynamic code generation alone.
#
#
# - [QRAFTI github repo](https://github.com/terence-lim/quant-agents)

# %% [markdown]
# # 2. Financial Data Science
#
# As financial markets produce vast volumes of structured and unstructured data,
# the ability to extract insights and develop predictive models has become increasingly important.
# [Financial Data Science Python Notebooks](https://terence-lim.github.io/docs/financial-data-science-notebooks/)
# provide a practical guide for analysts, researchers, and data scientists looking to apply Python
# and its broad ecosystem of libraries, tools, frameworks, and community resources
# to financial analysis, econometrics, and machine learning.
#
# Designed to support financial data science workflows, the companion [FinDS Python package](https://github.com/terence-lim/financial-data-science) demonstrates how to use database engines such as SQL, Redis, and MongoDB to manage and access large datasets, including:
#
# 1. Core financial databases such as CRSP, Compustat, IBES, and TAQ
#
# 2. Public economic data APIs from sources like FRED and the Bureau of Economic Analysis (BEA)
#
# 3. Structured and unstructured data from academic and research websites
#
# In addition to data access, it provides practical examples and templates for applying:
#
# 1. Financial econometrics and time series modeling
#
# 2. Graph analytics, event studies, and backtesting strategies
#
# 3. Machine learning for predictive analytics
#
# 4. Natural language processing (NLP) to extract insights from financial text
#
# 5. Neural networks and large language models (LLMs) for advanced decision-making
#
#
# **Documentation**
#
# - [Financial Data Science Notebooks](https://terence-lim.github.io/docs/financial-data-science-notebooks/)
#
# - [Download as PDF book](https://terence-lim.github.io/docs/financial-data-science-notebooks.pdf)
#
# - [FinDS API reference](https://terence-lim.github.io/docs/financial-data-science/)
#
#
# **Github repos**
#
# - [FinDS package](https://github.com/terence-lim/financial-data-science)
#
# - [Jupyter notebooks](https://github.com/terence-lim/financial-data-science-notebooks)

# %% [markdown]
# # 3. Solving Actuarial Math with Python
#
# The _actuarialmath_ Python package implements fundamental methods for modeling life contingent risks, and closely follows traditional topics covered in actuarial exams and standard texts such as the "Fundamentals of Actuarial Math - Long-term" exam syllabus by the Society of Actuaries, and "Actuarial Mathematics for Life Contingent Risks" by Dickson, Hardy and Waters.
#
# __Installation__
#
# `pip install actuarialmath`
#
#
# __Resources__
#
# - [Jupyter notebook](https://terence-lim.github.io/notes/faml.ipynb), or [run in Colab](https://colab.research.google.com/github/terence-lim/terence-lim.github.io/blob/master/notes/faml.ipynb), to solve all sample SOA FAM-L exam questions
#
# - [User Guide](https://actuarialmath-guide.readthedocs.io/en/latest/), or [download pdf](https://terence-lim.github.io/notes/actuarialmath-guide.pdf)
#
# - [API reference](https://actuarialmath.readthedocs.io/en/latest/)
#
# - [Github repo](https://github.com/terence-lim/actuarialmath.git) and [issues](https://github.com/terence-lim/actuarialmath/issues)

# %% [markdown]
# # 4. OCaml LLVM
#
# MiniMat matrix language
#
# - <https://github.com/terence-lim/minimat>

# %% [markdown]
# # Publications
#
#
# Lim, T., Muthuraman, K., & Sury, M. (2026). *QRAFTI: An agentic framework for empirical research in quantitative finance* [Preprint]. arXiv
#
# Yi, S., Nguyen, J., Xu, H., Lim, T., Skrovan, J., Beri, M., Modi, H., Well, A., Mery, C. M., Zhang, Y., Markey, M. K., & Ding, Y. (2026). *Automated thematic analysis for clinical qualitative data: Iterative codebook refinement with full provenance* [Preprint]. arXiv. [https://doi.org/10.48550/arXiv.2603.08989](https://doi.org/10.48550/arXiv.2603.08989)
#
# Yi, S., Nguyen, J., Lim, T., Well, A., Skrovan, J., Beri, M., Lee, Y., Radhakrishnan, K., Leqi, L., Markey, M., & Ding, Y. (2025). *Position: Thematic analysis of unstructured clinical transcripts with large language models* [Conference workshop presentation]. GenAI4Health Workshop at NeurIPS 2025, Vancouver, Canada. [https://doi.org/10.48550/arXiv.2509.14597](https://doi.org/10.48550/arXiv.2509.14597)
#
# Yi, S., Nguyen, J., Xu, H., Lim, T., Skrovan, J., Beri, M., Modi, H., Well, A., Leqi, L., Markey, M., & Ding, Y. (2025). *SFT-TA: Supervised fine-tuned agents in multi-agent LLMs for automated inductive thematic analysis* [Preprint]. arXiv. [https://doi.org/10.48550/arXiv.2509.17167](https://doi.org/10.48550/arXiv.2509.17167)
#
# Yi, S., Nguyen, J., Xu, H., Lim, T., Well, A., & Ding, Y. *Auto-TA: Towards scalable automated thematic analysis (TA) via multi-agent large language models with reinforcement learning* [Preprint]. (2025). arXiv. [https://doi.org/10.48550/arXiv.2506.23998](https://doi.org/10.48550/arXiv.2506.23998)
#
# Xu, H., Yi, S., Lim, T., Xu, J., Well, A., Mery, C., Zhang, A., Zhang, Y., Ji, H., Pingali, K., Leng, Y., & Ding, Y. (2025). *TAMA: A human-AI collaborative thematic analysis framework using multi-agent LLMs for clinical interviews* [Preprint]. arXiv. [https://arxiv.org/abs/2503.20666](https://arxiv.org/abs/2503.20666)
#
# Raza, M. Z., Xu, J., Lim, T., Boddy, L., Mery, C. M., Well, A., & Ding, Y. (2025). *LLM-TA: An LLM-enhanced thematic analysis pipeline for transcripts from parents of children with congenital heart disease* [Conference workshop presentation]. GenAI4Health Workshop at AAAI 2025, Philadelphia, Pennsylvania. [https://doi.org/10.48550/arXiv.2502.01620](https://doi.org/10.48550/arXiv.2502.01620)
#
# Alford, A., Jones, R., & Lim, T. (2012). Quantitative equity portfolio management. In F. J. Fabozzi (Ed.), *Encyclopedia of financial models*. John Wiley & Sons. [https://doi.org/10.1002/9781118182635.efm0048](https://doi.org/10.1002/9781118182635.efm0048)
#
# Alford, A., Jones, R., & Lim, T. (2011). Quantitative equity portfolio management. In F. J. Fabozzi & H. M. Markowitz (Eds.), *The theory and practice of investment management: Asset allocation, valuation, portfolio construction, and strategies* (2nd ed.). John Wiley & Sons. [https://doi.org/10.1002/9781118267028.ch11](https://doi.org/10.1002/9781118267028.ch11)
#
# Alford, A., Jones, R., & Lim, T. (2008). Quantitative equity portfolio management. In F. J. Fabozzi (Ed.), *Handbook of finance* (Vol. 2). John Wiley & Sons. [https://doi.org/10.1002/9780470404324.hof002029](https://doi.org/10.1002/9780470404324.hof002029)
#
# Lim, T. (2010). *Measuring the value of corporate philanthropy: Social impact, business benefits, and investor returns*. Committee Encouraging Corporate Philanthropy. [ISBN: 978-0-615-34109-5](https://hollis.harvard.edu/discovery/fulldisplay?context=L&vid=01HVD_INST:HVD2&lang=en&search_scope=MyInst_and_CI&adaptor=Local%20Search%20Engine&tab=Everything&docid=alma990133746670203941)
#
# Jones, R. C., Lim, T., & Zangari, P. J. (2007). The Black-Litterman model for structured equity portfolios. *The Journal of Portfolio Management, 33*(2), 24–33. [https://doi.org/10.3905/jpm.2007.674791](https://doi.org/10.3905/jpm.2007.674791)
#
# Lim, T., Lo, A. W., Merton, R. C., & Scholes, M. S. (2006). The derivatives sourcebook. *Foundations and Trends in Finance, 1*(5–6), 365–643. [https://doi.org/10.1561/0500000005](https://doi.org/10.1561/0500000005)
#
# Lim, T. (2001). Rationality and analysts’ forecast bias. *The Journal of Finance, 56*(1), 369–385. [https://doi.org/10.1111/0022-1082.00329](https://doi.org/10.1111/0022-1082.00329)
#
# Hong, H., Lim, T., & Stein, J. C. (2000). Bad news travels slowly: Size, analyst coverage, and the profitability of momentum strategies. *The Journal of Finance, 55*(1), 265–295. [https://doi.org/10.1111/0022-1082.00206](https://doi.org/10.1111/0022-1082.00206)

# %% [markdown]
# # Experience
#
# Silver Fern Healthcare, Old Saybrook, CT
#
# Graphen Inc, New York, NY
#
# Goldman Sachs Asset Management, New York, NY
#
# Chief Executives for Corporate Purpose (CECP), New York, NY
#
# Dartmouth College, Tuck School of Business, Hanover, NH
#
# Koeneman Capital Management, Singapore

# %% [markdown]
# # Education
#
# **Massachusetts Institute of Technology**
# - PhD in Finance, Sloan School of Management
#
# **Stanford University**
# - Master of Science in Electrical Engineering, School of Engineering
#
# **Columbia University**
# - Master of Science in Computer Science, School of Engineering and Applied Science.
#
# **The University of Texas at Austin**
# - Master of Science in Artificial Intelligence, College of Natural Sciences
# - Master of Science in Data Science, College of Natural Sciences
#
# **Harvard University**
# - Master of Public Health (expected 2028), Chan School of Public Health
#
# **Johns Hopkins University**
# - Master of Science in Applied Biomedical Engineering (expected 2030), Whiting School of Engineering
#
# **University of Pennsylvania**, Jerome Fisher Management and Technology Dual-Degree Program
# - Bachelor of Science in Economics (Wharton School) *summa cum laude*
# - Bachelor of Science in Engineering, major in Computer Science and Engineering, *summa cum laude*
#
# ## Awards
#
# Chase Manhattan International Foundation Scholarship (four-year full-ride).
#
# Q-Group research grant ($10,000)
#
# ## Certifications
#
# Associate of the Society of Actuaries (ASA). ID No. 358609.
#
# Chartered Alternative Investment Analyst (CAIA). Charter No. 659.
#
# Chartered Financial Analyst (CFA). Charter No. 143287.
#
# Certified Financial Planner (CFP). CFP Board ID: 107488.
#
# Certified Management Accountant (CMA), Institute of Management Accountants. Certificate No. 140947.
#
# Certified Public Accountant (CPA), South Dakota Board of Accountancy. Certificate No. 1361.
#
# Financial Risk Manager (FRM), Global Association of Risk Professionals. GARP ID: 1806536.
